# %% [markdown]
# <a href="https://colab.research.google.com/github/hyohyeon08/HornGongMer/blob/main/5_%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 21.0,
       21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 22.5, 22.7,
       23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 27.3, 27.5, 27.5,
       27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 36.5, 36.0, 37.0, 37.0,
       39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 40.0, 42.0, 43.0, 43.0, 43.5,
       44.0])
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(perch_length, perch_weight, random_state=42)
#훈련세트와 테스트 세트를 2차워 배열로 바꾸기
train_input = train_input.reshape(-1, 1)
test_input = test_input.reshape(-1, 1)

# %%
from sklearn.neighbors import KNeighborsRegressor

knr = KNeighborsRegressor(n_neighbors=3)

knr.fit(train_input, train_target)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
print(knr.predict([[50]]))
# Out:
# [1033.33333333]

# %%
import matplotlib.pyplot as plt

distance, indexes = knr.kneighbors([[50]])

plt.scatter(train_input, train_target)
plt.scatter(train_input[indexes], train_target[indexes], marker="D")

plt.scatter(50, 1033, marker="^")
plt.xlabel("lengh")
plt.ylabel("weight")
plt.show()

# %%
print(np.mean(train_target[indexes]))
# Out:
# 1033.3333333333333

# %%
print(knr.predict([[100]]))
# Out:
# [1033.33333333]

# %%
distance, indexes = knr.kneighbors([[100]])

plt.scatter(train_input, train_target)

#훈련 세트 중에서 이웃 셈플만 다시 그립니다.
plt.scatter(train_input[indexes], train_target[indexes], marker="D")

plt.scatter(100, 1033, marker="^")
plt.xlabel('lengh')
plt.ylabel('weight')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(train_input, train_target)

print(lr.predict([[50]]))
# Out:
# [1241.83860323]

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [39.01714496] -709.0186449535477

# %%
plt.scatter(train_input, train_target)

plt.plot([15, 50], [15 * lr.coef_ + lr.intercept_, 50 * lr.coef_ + lr.intercept_])

plt.scatter(50, 1241.8, marker="^")
plt.xlabel('lengh')
plt.ylabel('weight')
plt.show()

# %%
print(lr.score(train_input, train_target))
print(lr.score(test_input, test_target))
# Out:
# 0.939846333997604
# 0.8247503123313558

# %%
train_poly = np.column_stack((train_input ** 2, train_input))
test_poly = np.column_stack((test_input ** 2, test_input))

# %%
print(train_poly)
# Out:
# [[ 384.16   19.6 ]
#  [ 484.     22.  ]
#  [ 349.69   18.7 ]
#  [ 302.76   17.4 ]
#  [1296.     36.  ]
#  [ 625.     25.  ]
#  [1600.     40.  ]
#  [1521.     39.  ]
#  [1849.     43.  ]
#  [ 484.     22.  ]
#  [ 400.     20.  ]
#  [ 484.     22.  ]
#  [ 576.     24.  ]
#  [ 756.25   27.5 ]
#  [1849.     43.  ]
#  [1600.     40.  ]
#  [ 576.     24.  ]
#  [ 441.     21.  ]
#  [ 756.25   27.5 ]
#  [1600.     40.  ]
#  [1075.84   32.8 ]
#  [ 702.25   26.5 ]
#  [1332.25   36.5 ]
#  [ 187.69   13.7 ]
#  [ 515.29   22.7 ]
#  [ 225.     15.  ]
#  [1369.     37.  ]
#  [1225.     35.  ]
#  [ 823.69   28.7 ]
#  [ 552.25   23.5 ]
#  [1521.     39.  ]
#  [ 441.     21.  ]
#  [ 529.     23.  ]
#  [ 484.     22.  ]
#  [1936.     44.  ]
#  [ 506.25   22.5 ]
#  [ 361.     19.  ]
#  [1369.     37.  ]
#  [ 484.     22.  ]
#  [ 655.36   25.6 ]
#  [1764.     42.  ]
#  [1190.25   34.5 ]]

# %%
print(test_poly)
# Out:
# [[  70.56    8.4 ]
#  [ 324.     18.  ]
#  [ 756.25   27.5 ]
#  [ 453.69   21.3 ]
#  [ 506.25   22.5 ]
#  [1600.     40.  ]
#  [ 900.     30.  ]
#  [ 605.16   24.6 ]
#  [1521.     39.  ]
#  [ 441.     21.  ]
#  [1892.25   43.5 ]
#  [ 262.44   16.2 ]
#  [ 784.     28.  ]
#  [ 745.29   27.3 ]]

# %%
print(train_poly.shape, test_poly.shape)
# Out:
# (42, 2) (14, 2)

# %%
lr = LinearRegression()
lr.fit(train_poly, train_target)

print(lr.predict([[50 ** 2, 50]]))
# Out:
# [1573.98423528]

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [  1.01433211 -21.55792498] 116.0502107827827

# %%
point = np.arange(15, 50)

plt.scatter(train_input, train_target)

plt.plot(point, 1.01*point**2 - 21.6*point + 116.05)

plt.scatter(50, 1574, marker="^")
plt.xlabel('lengh')
plt.ylabel('weight')
plt.show()

# %%
print(lr.score(train_poly, train_target))
print(lr.score(test_poly, test_target))
# Out:
# 0.9706807451768623
# 0.9775935108325122
